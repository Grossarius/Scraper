# %%
# Try scraping traderjoe 
import json
import requests 

# Initialize query 
query = """
query SearchProduct($sku: String, $storeCode: String = "TJ", $published: String = "1") {
  products(
    filter: {sku: {eq: $sku}, store_code: {eq: $storeCode}, published: {eq: $published}}
  ) {
    items {
      category_hierarchy {
        id
        url_key
        description
        name
        position
        level
        created_at
        updated_at
        product_count
        __typename
      }
      item_story_marketing
      product_label
      fun_tags
      primary_image
      primary_image_meta {
        url
        metadata
        __typename
      }
      other_images
      other_images_meta {
        url
        metadata
        __typename
      }
      context_image
      context_image_meta {
        url
        metadata
        __typename
      }
      published
      sku
      url_key
      name
      item_description
      item_title
      item_characteristics
      item_story_qil
      use_and_demo
      sales_size
      sales_uom_code
      sales_uom_description
      country_of_origin
      availability
      new_product
      promotion
      price_range {
        minimum_price {
          final_price {
            currency
            value
            __typename
          }
          __typename
        }
        __typename
      }
      retail_price
      nutrition {
        display_sequence
        panel_id
        panel_title
        serving_size
        calories_per_serving
        servings_per_container
        details {
          display_seq
          nutritional_item
          amount
          percent_dv
          __typename
        }
        __typename
      }
      ingredients {
        display_sequence
        ingredient
        __typename
      }
      allergens {
        display_sequence
        ingredient
        __typename
      }
      created_at
      first_published_date
      last_published_date
      updated_at
      related_products {
        sku
        item_title
        primary_image
        primary_image_meta {
          url
          metadata
          __typename
        }
        price_range {
          minimum_price {
            final_price {
              currency
              value
              __typename
            }
            __typename
          }
          __typename
        }
        retail_price
        sales_size
        sales_uom_description
        category_hierarchy {
          id
          name
          __typename
        }
        __typename
      }
      __typename
    }
    total_count
    page_info {
      current_page
      page_size
      total_pages
      __typename
    }
    __typename
  }
}
"""

json_data = {
    'query': query,
    'variables': {"storeCode": "TJ", "published": "1", "sku": "068663"}
}

response = requests.post('https://www.traderjoes.com/api/graphql', json=json_data)
response.json()
# print(json.dumps(response.json(), indent=2))
# Out:
# {'data': {'products': {'items': [{'category_hierarchy': [{'id': 2,
#        'url_key': 'default-category',
#        'description': None,
#        'name': 'Products',
#        'position': 1,
#        'level': 1,
#        'created_at': '2020-11-17 20:49:52',
#        'updated_at': '2021-02-18 08:22:08',
#        'product_count': 9,
#        '__typename': 'CategoryTree'},
#       {'id': 8,
#        'url_key': 'food',
#        'description': None,
#        'name': 'Food',
#        'position': 2,
#        'level': 2,
#        'created_at': '2021-02-18 08:22:02',
#        'updated_at': '2021-02-25 09:03:46',
#        'product_count': 2,
#        '__typename': 'CategoryTree'},
#       {'id': 59,
#        'url_key': 'dips-sauces-dressings',
#        'description': None,
#        'name': 'Dips, Sauces & Dressings',
#        'position': 4,
#        'level': 3,
#        'created_at': '2021-02-18 08:22:04',
#        'updated_at': '2021-02-18 08:22:04',
#        'product_count': 0,
#        '__typename': 'CategoryTree'},
#       {'id': 62,
#        'url_key': 'condiments',
#        'description': None,
#        'name': 'Condiments',
#        'position': 1,
#        'level': 4,
#        'created_at': '2021-02-18 08:22:04',
#        'updated_at': '2021-05-15 00:36:23',
#        'product_count': 18,
#        '__typename': 'CategoryTree'}],
#      'item_story_marketing': '<p>Ginger is so utterly unique in its flavor, aroma, and even the physical sensations it creates in the mouth, that it almost feels like a culinary gift from nature itself. It’s honestly hard to imagine what global cuisine would look like (or, more importantly, taste like) without this singularly scrumptious root. And now, there’s an easy way to incorporate its inimitable flavor profile to any dish you wish: Trader Joe’s Thai Sweet Ginger Sauce combines the savory, herby sensations of ginger with the rich sweetness of coconut sugar, a touch of pickled garlic, and just a bit of soy sauce to make one seriously versatile condiment. You get sweet, spicy, salty, and garlicky — all in a single sauce.</p>\r\n<p>Made especially for us by a trusted supplier in Thailand, this Sweet Ginger Sauce is practically perfect for serving with a plate of pan-fried Pork Gyoza, but that’s hardly where we’d stop. In fact, we find that its sweet, ginger-y heat makes for excellent dunking with all kinds of savory, meaty dishes, including chicken skewers, samosas, or crispy fried shrimp. Of course, we haven’t forgotten plant-based options: try pouring a bit of our Thai Sweet Ginger Sauce over garlic-fried rice or sautéed Tempeh, or mix with a bit of olive oil and vinegar for a sweet, snappy salad dressing.</p>',
#      'product_label': None,
#      'fun_tags': ['Feeling Adventurous', 'The "X" Factor'],
#      'primary_image': '/content/dam/trjo/products/m20405/68663.png',
#      'primary_image_meta': {'url': '/content/dam/trjo/products/m20405/68663.png',
#       'metadata': '{"src":"/content/dam/trjo/products/m20405/68663.png/jcr:content/renditions/cq5dam.web.1280.1280","srcSet":[{"src":"/content/dam/trjo/products/m20405/68663.png/jcr:content/renditions/webp-640.webp","media":"(max-width: 847px)","type":"image/webp"},{"src":"/content/dam/trjo/products/m20405/68663.png/jcr:content/renditions/webp-1280.webp","media":"(min-width: 848px)","type":"image/webp"}],"srcOriginal":"/content/dam/trjo/products/m20405/68663.png"}',
#       '__typename': 'ImageWithMeta'},
#      'other_images': [],
#      'other_images_meta': [],
#      'context_image': '/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg',
#      'context_image_meta': {'url': '/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg',
#       'metadata': '{"src":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg/jcr:content/renditions/cq5dam.web.1280.1280.jpeg","srcSet":[{"src":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg/jcr:content/renditions/webp-640.webp","media":"(max-width: 847px)","type":"image/webp"},{"src":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg/jcr:content/renditions/webp-1280.webp","media":"(min-width: 848px)","type":"image/webp"},{"src":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg/jcr:content/renditions/cq5dam.web.1280.1280.jpeg","media":"(min-width: 848px)","type":"image/jpeg"},{"src":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg/jcr:content/renditions/cq5dam.web.640.640.jpeg","media":"(max-width: 847px)","type":"image/jpeg"}],"alt":"Trader Joe\'s Thai Sweet Ginger Sauce bottle flat on wood table; bowl of noodles & vegetables mixed with sauce","srcOriginal":"/content/dam/trjo/context-images/68663-thai-sweet-ginger-sauce-pdp.jpg"}',
#       '__typename': 'ImageWithMeta'},
#      'published': 1,
#      'sku': '068663',
#      'url_key': '068663-sweet-thai-ginger-sauce',
#      'name': 'SWEET THAI GINGER SAUCE',
#      'item_description': None,
#      'item_title': 'Thai Sweet Ginger Sauce',
#      'item_characteristics': None,
#      'item_story_qil': "Ginger is so utterly unique in its flavor, aroma, and even the physical sensations it creates in the mouth, that it \nalmost feels like a culinary gift from nature itself. It's honestly hard to imagine what global cuisine would look \nlike (or, more importantly, taste like) without this singularly scrumptious root. And now, there's an easy way to \nincorporate its inimitable flavor profile to any dish you wish: Trader Joe's Thai Sweet Ginger Sauce combines \nthe savory, herby sensations of ginger with the rich sweetness of coconut sugar, a touch of pickled garlic, and \njust a bit of soy sauce to make one seriously versatile condiment. You get sweet, spicy, salty, and garlicky - all \nin a single sauce.\n\nMade especially for us by a trusted supplier in Thailand, this Sweet Ginger Sauce is practically perfect for \nserving with a plate of pan-fried Pork Gyoza [sku 10602], but that's hardly where we'd stop. In fact, we find that \nits sweet, ginger-y heat makes for excellent dunking with all kinds of savory, meaty dishes, including chicken \nskewers, samosas, or crispy fried shrimp. Of course, we haven't forgotten plant-based options: try pouring a bit  \nof our Thai Sweet Ginger Sauce over garlic-fried rice or sautéed Tempeh [sku 99125], or mix with a bit of olive \noil and vinegar for a sweet, snappy salad dressing.\n\nThai Sweet Ginger Sauce",
#      'use_and_demo': None,
#      'sales_size': 10.1,
#      'sales_uom_code': '198',
#      'sales_uom_description': 'Fl Oz',
#      'country_of_origin': 'Product of Thailand',
#      'availability': '1',
#      'new_product': '0',
#      'promotion': None,
#      'price_range': {'minimum_price': {'final_price': {'currency': 'USD',
#         'value': 2.49,
#         '__typename': 'Money'},
#        '__typename': 'ProductPrice'},
#       '__typename': 'PriceRange'},
#      'retail_price': '2.49',
#      'nutrition': [{'display_sequence': 0,
#        'panel_id': 1,
#        'panel_title': '',
#        'serving_size': '2 Tbsp (30mL)',
#        'calories_per_serving': '50 ',
#        'servings_per_container': 'Serves 10',
#        'details': [{'display_seq': 1,
#          'nutritional_item': 'Total Fat',
#          'amount': '0.5 g',
#          'percent_dv': '.01',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 2,
#          'nutritional_item': 'Saturated Fat',
#          'amount': '0 g',
#          'percent_dv': '0',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 3,
#          'nutritional_item': 'Trans Fat',
#          'amount': '0 g',
#          'percent_dv': '',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 4,
#          'nutritional_item': 'Cholesterol',
#          'amount': '0 mg',
#          'percent_dv': '0',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 5,
#          'nutritional_item': 'Sodium',
#          'amount': '480 mg',
#          'percent_dv': '.21',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 6,
#          'nutritional_item': 'Total Carbohydrate',
#          'amount': '10 g',
#          'percent_dv': '.04',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 7,
#          'nutritional_item': 'Dietary Fiber',
#          'amount': 'less than 1 g',
#          'percent_dv': '.03',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 8,
#          'nutritional_item': 'Total Sugars',
#          'amount': '8 g',
#          'percent_dv': '',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 9,
#          'nutritional_item': 'Includes',
#          'amount': '7 g Added Sugars',
#          'percent_dv': '.14',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 10,
#          'nutritional_item': 'Protein',
#          'amount': 'less than 1 g',
#          'percent_dv': '',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 11,
#          'nutritional_item': 'Vitamin D',
#          'amount': '',
#          'percent_dv': '0',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 12,
#          'nutritional_item': 'Calcium',
#          'amount': '',
#          'percent_dv': '.02',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 13,
#          'nutritional_item': 'Iron',
#          'amount': '',
#          'percent_dv': '.04',
#          '__typename': 'NutritionDetails'},
#         {'display_seq': 14,
#          'nutritional_item': 'Potassium',
#          'amount': '',
#          'percent_dv': '.02',
#          '__typename': 'NutritionDetails'}],
#        '__typename': 'NutritionAttribute'}],
#      'ingredients': [{'display_sequence': 1,
#        'ingredient': 'WATER',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 2,
#        'ingredient': 'COCONUT SUGAR',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 3,
#        'ingredient': 'PICKLED GARLIC (GARLIC, SUGAR, SALT, WATER, DISTILLED VINEGAR)',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 4,
#        'ingredient': 'GINGER',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 5,
#        'ingredient': 'DISTILLED VINEGAR',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 6,
#        'ingredient': 'GARLIC',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 7,
#        'ingredient': 'FERMENTED SOY BEAN PASTE (SOYBEAN, BRINE [WATER, SALT], WHEAT)',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 8,
#        'ingredient': 'SOY SAUCE (WATER, SOYBEAN, SALT, WHEAT, SUGAR)',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 9,
#        'ingredient': 'SUGAR',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 10,
#        'ingredient': 'PICKLED RED CHILI (RED CHILI, SALT, ACETIC ACID)',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 11,
#        'ingredient': 'CORIANDER',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 12,
#        'ingredient': 'MODIFIED TAPIOCA STARCH',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 13,
#        'ingredient': 'RICE BRAN OIL',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 14,
#        'ingredient': 'SALT',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 15,
#        'ingredient': 'SESAME SEED',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 16,
#        'ingredient': 'DARK SOY SAUCE (MOLASSES, WATER, SALT, SOY SAUCE [BRINE {WATER,SALT}, SOYBEAN, WHEAT FLOUR])',
#        '__typename': 'IngredientsAttribute'},
#       {'display_sequence': 17,
#        'ingredient': 'XANTHAN GUM.',
#        '__typename': 'IngredientsAttribute'}],
#      'allergens': [{'display_sequence': 1,
#        'ingredient': 'CONTAINS SOY, SESAME, WHEAT, COCONUT.',
#        '__typename': 'IngredientsAttribute'}],
#      'created_at': '2021-06-30 21:55:13',
#      'first_published_date': '2023-05-31 21:55:32',
#      'last_published_date': '2023-05-31 21:55:32',
#      'updated_at': '2023-06-28 18:55:04',
#      'related_products': [],
#      '__typename': 'SimpleProduct'}],
#    'total_count': 1,
#    'page_info': {'current_page': 1,
#     'page_size': 20,
#     'total_pages': 1,
#     '__typename': 'SearchResultPageInfo'},
#    '__typename': 'Products'}}}
